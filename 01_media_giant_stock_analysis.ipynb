# %% [markdown]
# # Theme Park Stock Analysis
# ## Import packages and ticker list

# %%
# Install yfinance package
# !pip install yfinance
# !pip install pandas_datareader
# !pip install alpha_vantage
# Import required libraries

from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as web

# %%
API_KEY = "

# %%
sns.set(style='whitegrid')

tickers = ["DIS", "CMCSA", "SEAS", "SIX", "FUN"]

data={}

for ticker in tickers:
    print(f"Downloading {ticker} from Stooq...")
    try:
        df = web.DataReader(ticker, "stooq")
        df = df.sort_index() # Stooq returns newest first
        
        df.columns = df.columns.str.lower() # normalize column names

        data[ticker] = df
    except Exception as e:
        print(f"Failed to download {ticker}: {e}")

df.head()
# Out:
# ...
#                open     high      low    close         volume
# Date
# 2021-02-05  44.3625  45.2892  43.1697  43.1894  530124.619392
# 2021-02-08  43.5542  44.6583  43.3964  43.7218  477961.691754
# 2021-02-09  43.9189  44.3511  43.4128  43.5739  251850.656557
# 2021-02-10  43.7710  44.2739  42.9824  43.3077  294981.639817
# 2021-02-11  43.8006  43.8006  41.9078  42.2430  622112.700694

# %%
for t in data:
    print(t, data[t].columns)
# Out:
# DIS Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')
# CMCSA Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')
# SEAS Index([], dtype='object')
# SIX Index([], dtype='object')
# FUN Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')
